# %% [markdown]
# ## 1. What is Seaborn?

# %% [markdown]
# --Seaborn is a data visualization library built on top of Matplotlib.
#
# --It makes complex plots simpler and prettier.
#
# --Where Matplotlib needs 10+ lines, Seaborn often needs 2–3 lines.

# %% [markdown]
# ## 2. Install & Import

# %% [markdown]
# pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Built-in Datasets

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
flights = sns.load_dataset("flights")

print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 4. First Plots with Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
tips = sns.load_dataset("tips")

# %% [markdown]
# Scatter plot

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title("Scatterplot of Bill vs Tip")
plt.show()

# %% [markdown]
# Bar Plot

# %%
sns.barplot(x="day", y="total_bill", data=tips, estimator=sum)
plt.title("Total Bill per Day")
plt.show()

# %% [markdown]
# Line Plot

# %%
flights = sns.load_dataset("flights")
sns.lineplot(x="year", y="passengers", data=flights)
plt.title("Yearly Flight Passengers")
plt.show()
