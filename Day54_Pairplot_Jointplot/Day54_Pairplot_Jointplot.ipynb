# %% [markdown]
# # 1. Pairplot – Pairwise Relationships

# %%
import seaborn as sns 
import matplotlib.pyplot as plp 

iris = sns.load_dataset("iris")
sns.pairplot(iris)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 iris = sns.load_dataset("iris")
#       5 sns.pairplot(iris)
# ----> 6 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # 2. Pairplot with Hue (Categorical Coloring)

# %%
sns.pairplot(iris, hue="species", palette="Set2")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 sns.pairplot(iris, hue="species", palette="Set2")
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # 3. Jointplot – Focus on Two Variables

# %%
sns.jointplot(data = iris, x = "sepal_length" , y = "sepal_width")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 sns.jointplot(data = iris, x = "sepal_length" , y = "sepal_width")
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # 4. Jointplot with Different Kinds

# %%
# Scatter + regression line
sns.jointplot(data=iris, x="sepal_length", y="sepal_width", kind="reg")

# Hexbin style
sns.jointplot(data=iris, x="sepal_length", y="sepal_width", kind="hex")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       4 # Hexbin style
#       5 sns.jointplot(data=iris, x="sepal_length", y="sepal_width", kind="hex")
# ----> 6 plt.show()
#
# NameError: name 'plt' is not defined
